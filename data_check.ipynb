# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = [0.391, 0.392, 0.391, 0.391]
b = [0.418, 0.419, 0.418, 0.417]
print('mean:', np.mean(a), 'std:', np.std(a))
print('mean:', np.mean(b), 'std:', np.std(b))
# Out:
# mean: 0.39125 std: 0.0004330127018922198
# mean: 0.418 std: 0.0007071067811865482

# %%
a = [0.330, 0.330, 0.330, 0.329]
b = [0.381, 0.381, 0.381, 0.381]
print('mean:', np.mean(a), 'std:', np.std(a))
print('mean:', np.mean(b), 'std:', np.std(b))
# Out:
# mean: 0.32975 std: 0.0004330127018922197
# mean: 0.381 std: 0.0

# %%
a = [0.216, 0.215, 0.215, 0.215]
b = [0.249, 0.248, 0.248, 0.248]
print('mean:', np.mean(a), 'std:', np.std(a))
print('mean:', np.mean(b), 'std:', np.std(b))
# Out:
# mean: 0.21525 std: 0.00043301270189221973
# mean: 0.24825 std: 0.00043301270189221973

# %%
a = [0.177, 0.177, 0.177, 0.176]
b = [0.215, 0.215, 0.215, 0.214]
print('mean:', np.mean(a), 'std:', np.std(a))
print('mean:', np.mean(b), 'std:', np.std(b))
# Out:
# mean: 0.17674999999999996 std: 0.0004330127018922197
# mean: 0.21475 std: 0.0004330127018922197

# %%
import json
filepath = './rep_store.npy'
data = np.load(filepath, allow_pickle=True)
print(data.item().keys())
# Out:
# dict_keys(['rep0', 'rep1', 'rep2', 'rep3'])

# %%
r0, r1, r2, r3 = data.item()['rep0'][:,0,:], data.item()['rep1'][:,0,:], data.item()['rep2'][:,0,:], data.item()['rep3'][:,0,:]
print(r0.shape, r1.shape, r2.shape, r3.shape)
# Out:
# (97, 2048) (97, 2048) (97, 2048) (97, 2048)

# %%
from sklearn.manifold import TSNE
X_embedded = TSNE(n_components=2, learning_rate='auto',
                  init='random', perplexity=3).fit_transform(r0)
X_embedded.shape
plt.scatter(X_embedded[:, 0], X_embedded[:, 1])
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
